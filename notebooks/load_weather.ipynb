# %% [markdown]
# ## import necessary packages

# %%
from pymongo import MongoClient
import pandas as pd

# %% [markdown]
# ## Import weather data and convert to DataFrame

# %% [markdown]
# ### access mongo db

# %%
client = MongoClient()

# %%
ferry_db = client['ferry']

# %%
weather = ferry_db['weather']

# %% [markdown]
# ### examine record structure for weather

# %%
weather.find_one()
# Out:
# {'_id': ObjectId('5e86586d17b20f91ad7ec965'),
#  'latitude': 47.811784,
#  'longitude': -122.38325,
#  'timezone': 'America/Los_Angeles',
#  'daily': {'data': [{'time': 1481961600,
#     'summary': 'Overcast throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1481990100,
#     'sunsetTime': 1482020400,
#     'moonPhase': 0.66,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipIntensityMaxTime': 1482012060,
#     'precipProbability': 0,
#     'temperatureHigh': 33.3,
#     'temperatureHighTime': 1482017880,
#     'temperatureLow': 27.46,
#     'temperatureLowTime': 1482037440,
#     'apparentTemperatureHigh': 32.8,
#     'apparentTemperatureHighTime': 1482017880,
#     'apparentTemperatureLow': 27.95,
#     'apparentTemperatureLowTime': 1482037440,
#     'dewPoint': 21.51,
#     'humidity': 0.76,
#     'pressure': 1029.9,
#     'windSpeed': 1.15,
#     'windGust': 3.24,
#     'windGustTime': 1482005460,
#     'windBearing': 95,
#     'cloudCover': 0.76,
#     'uvIndex': 1,
#     'uvIndexTime': 1482005100,
#     'visibility': 10,
#     'temperatureMin': 22.86,
#     'temperatureMinTime': 1481972100,
#     'temperatureMax': 33.3,
#     'temperatureMaxTime': 1482017880,
#     'apparentTemperatureMin': 23.35,
#     'apparentTemperatureMinTime': 1481972100,
#     'apparentTemperatureMax': 32.8,
#     'apparentTemperatureMaxTime': 1482017880}]},
#  'offset': -8,
#  'date': datetime.datetime(2016, 12, 17, 0, 0)}

# %% [markdown]
# ### Get all records, convert to a list

# %%
weather_data = list(weather.find())

# %% [markdown]
# ### Flatten information and add to weather_df

# %%
weather_df = pd.DataFrame()

# %%
for day in weather_data:
    day_df = pd.json_normalize(day['daily']['data'][0])
    day_df['date'] = day['date']
    weather_df = weather_df.append(day_df)

# %%
weather_df = weather_df.drop(columns=['time'])
weather_df.head()
# Out:
#                              summary               icon  sunriseTime  \
# 0       Overcast throughout the day.  partly-cloudy-day   1481990100
# 0                 Drizzle overnight.  partly-cloudy-day   1482076560
# 0     Light rain throughout the day.               rain   1482162960
# 0  Partly cloudy throughout the day.               rain   1482249420
# 0  Partly cloudy throughout the day.  partly-cloudy-day   1482335880
#
#    sunsetTime  moonPhase  precipIntensity  precipIntensityMax  \
# 0  1482020400       0.66           0.0000              0.0000
# 0  1482106800       0.69           0.0000              0.0004
# 0  1482193200       0.72           0.0124              0.0826
# 0  1482279660       0.75           0.0037              0.0634
# 0  1482366060       0.78           0.0002              0.0007
#
#    precipIntensityMaxTime  precipProbability  temperatureHigh  ...  \
# 0            1.482012e+09               0.00            33.30  ...
# 0            1.482131e+09               0.03            39.69  ...
# 0            1.482214e+09               0.91            43.78  ...
# 0            1.482221e+09               0.91            49.78  ...
# 0            1.482353e+09               0.10            45.85  ...
#
#    temperatureMax  temperatureMaxTime  apparentTemperatureMin  \
# 0           33.30          1482017880                   23.35
# 0           39.99          1482130800                   29.76
# 0           43.82          1482205260                   32.26
# 0           49.78          1482273900                   39.37
# 0           45.85          1482357600                   36.86
#
#    apparentTemperatureMinTime  apparentTemperatureMax  \
# 0                  1481972100                   32.80
# 0                  1482051540                   39.19
# 0                  1482155460                   43.32
# 0                  1482303600                   47.56
# 0                  1482324360                   45.35
#
#    apparentTemperatureMaxTime       date  precipType  precipAccumulation  \
# 0                  1482017880 2016-12-17         NaN                 NaN
# 0                  1482102060 2016-12-18         NaN                 NaN
# 0                  1482205260 2016-12-19        rain                 NaN
# 0                  1482276840 2016-12-20        rain                 NaN
# 0                  1482357600 2016-12-21        rain                 NaN
#
#    ozone
# 0    NaN
# 0    NaN
# 0    NaN
# 0    NaN
# 0    NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Combine weather data with wait data

# %% [markdown]
# ### Import wait data

# %%
ed_wait_df = pd.read_csv('../data/expanded/edmonds.csv')

# %%
ed_wait_df.head()
# Out:
#                         time tweet_text  wait_time  year  month  day  hour  \
# 0  2016-12-24 05:00:00-08:00        NaN        0.0  2016     12   24     5
# 1  2016-12-24 06:00:00-08:00        NaN        0.0  2016     12   24     6
# 2  2016-12-24 07:00:00-08:00        NaN        0.0  2016     12   24     7
# 3  2016-12-24 08:00:00-08:00        NaN        0.0  2016     12   24     8
# 4  2016-12-24 09:00:00-08:00        NaN        0.0  2016     12   24     9
#
#    dayofyear  week  weekday
# 0        359    51        5
# 1        359    51        5
# 2        359    51        5
# 3        359    51        5
# 4        359    51        5

# %% [markdown]
# ### Prep data frames for merging w/ datetime adjustments

# %%
ed_wait_df['time'] = pd.to_datetime(ed_wait_df['time'], utc=True)
ed_wait_df['time'] = ed_wait_df['time'].dt.tz_convert('US/Pacific')

# %%
weather_df['date'] = weather_df['date'].dt.tz_localize('US/Pacific')
# Out:
#                              summary               icon  sunriseTime  \
# 0       Overcast throughout the day.  partly-cloudy-day   1481990100
# 0                 Drizzle overnight.  partly-cloudy-day   1482076560
# 0     Light rain throughout the day.               rain   1482162960
# 0  Partly cloudy throughout the day.               rain   1482249420
# 0  Partly cloudy throughout the day.  partly-cloudy-day   1482335880
#
#    sunsetTime  moonPhase  precipIntensity  precipIntensityMax  \
# 0  1482020400       0.66           0.0000              0.0000
# 0  1482106800       0.69           0.0000              0.0004
# 0  1482193200       0.72           0.0124              0.0826
# 0  1482279660       0.75           0.0037              0.0634
# 0  1482366060       0.78           0.0002              0.0007
#
#    precipIntensityMaxTime  precipProbability  temperatureHigh  ...  \
# 0            1.482012e+09               0.00            33.30  ...
# 0            1.482131e+09               0.03            39.69  ...
# 0            1.482214e+09               0.91            43.78  ...
# 0            1.482221e+09               0.91            49.78  ...
# 0            1.482353e+09               0.10            45.85  ...
#
#    temperatureMax  temperatureMaxTime  apparentTemperatureMin  \
# 0           33.30          1482017880                   23.35
# 0           39.99          1482130800                   29.76
# 0           43.82          1482205260                   32.26
# 0           49.78          1482273900                   39.37
# 0           45.85          1482357600                   36.86
#
#    apparentTemperatureMinTime  apparentTemperatureMax  \
# 0                  1481972100                   32.80
# 0                  1482051540                   39.19
# 0                  1482155460                   43.32
# 0                  1482303600                   47.56
# 0                  1482324360                   45.35
#
#    apparentTemperatureMaxTime                      date  precipType  \
# 0                  1482017880 2016-12-17 00:00:00-08:00         NaN
# 0                  1482102060 2016-12-18 00:00:00-08:00         NaN
# 0                  1482205260 2016-12-19 00:00:00-08:00        rain
# 0                  1482276840 2016-12-20 00:00:00-08:00        rain
# 0                  1482357600 2016-12-21 00:00:00-08:00        rain
#
#    precipAccumulation  ozone
# 0                 NaN    NaN
# 0                 NaN    NaN
# 0                 NaN    NaN
# 0                 NaN    NaN
# 0                 NaN    NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Merge weather with wait time dataframe

# %%
ed_wait_df = pd.merge_asof(ed_wait_df, weather_df, left_on='time', right_on='date')

# %%
ed_wait_df.head().T
# Out:
#                                                             0  \
# time                                2016-12-24 05:00:00-08:00
# tweet_text                                                NaN
# wait_time                                                   0
# year                                                     2016
# month                                                      12
# day                                                        24
# hour                                                        5
# dayofyear                                                 359
# week                                                       51
# weekday                                                     5
# summary                      Possible drizzle in the evening.
# icon                                                     rain
# sunriseTime                                        1482595140
# sunsetTime                                         1482625380
# moonPhase                                                0.88
# precipIntensity                                        0.0028
# precipIntensityMax                                     0.0056
# precipIntensityMaxTime                             1.4826e+09
# precipProbability                                         0.5
# temperatureHigh                                         39.52
# temperatureHighTime                                1482613260
# temperatureLow                                          32.87
# temperatureLowTime                                 1482678660
# apparentTemperatureHigh                                 39.02
# apparentTemperatureHighTime                        1482613260
# apparentTemperatureLow                                  33.36
# apparentTemperatureLowTime                         1482678660
# dewPoint                                                34.38
# humidity                                                  0.9
# pressure                                               1013.1
# windSpeed                                                0.84
# windGust                                                 2.53
# windGustTime                                       1482614880
# windBearing                                                52
# cloudCover                                               0.96
# uvIndex                                                     1
# uvIndexTime                                        1482610080
# visibility                                                 10
# temperatureMin                                          34.38
# temperatureMinTime                                 1482643680
# temperatureMax                                          39.52
# temperatureMaxTime                                 1482613260
# apparentTemperatureMin                                  34.87
# apparentTemperatureMinTime                         1482643680
# apparentTemperatureMax                                  39.02
# apparentTemperatureMaxTime                         1482613260
# date                                2016-12-24 00:00:00-08:00
# precipType                                               rain
# precipAccumulation                                        NaN
# ozone                                                     NaN
#
#                                                             1  \
# time                                2016-12-24 06:00:00-08:00
# tweet_text                                                NaN
# wait_time                                                   0
# year                                                     2016
# month                                                      12
# day                                                        24
# hour                                                        6
# dayofyear                                                 359
# week                                                       51
# weekday                                                     5
# summary                      Possible drizzle in the evening.
# icon                                                     rain
# sunriseTime                                        1482595140
# sunsetTime                                         1482625380
# moonPhase                                                0.88
# precipIntensity                                        0.0028
# precipIntensityMax                                     0.0056
# precipIntensityMaxTime                             1.4826e+09
# precipProbability                                         0.5
# temperatureHigh                                         39.52
# temperatureHighTime                                1482613260
# temperatureLow                                          32.87
# temperatureLowTime                                 1482678660
# apparentTemperatureHigh                                 39.02
# apparentTemperatureHighTime                        1482613260
# apparentTemperatureLow                                  33.36
# apparentTemperatureLowTime                         1482678660
# dewPoint                                                34.38
# humidity                                                  0.9
# pressure                                               1013.1
# windSpeed                                                0.84
# windGust                                                 2.53
# windGustTime                                       1482614880
# windBearing                                                52
# cloudCover                                               0.96
# uvIndex                                                     1
# uvIndexTime                                        1482610080
# visibility                                                 10
# temperatureMin                                          34.38
# temperatureMinTime                                 1482643680
# temperatureMax                                          39.52
# temperatureMaxTime                                 1482613260
# apparentTemperatureMin                                  34.87
# apparentTemperatureMinTime                         1482643680
# apparentTemperatureMax                                  39.02
# apparentTemperatureMaxTime                         1482613260
# date                                2016-12-24 00:00:00-08:00
# precipType                                               rain
# precipAccumulation                                        NaN
# ozone                                                     NaN
#
#                                                             2  \
# time                                2016-12-24 07:00:00-08:00
# tweet_text                                                NaN
# wait_time                                                   0
# year                                                     2016
# month                                                      12
# day                                                        24
# hour                                                        7
# dayofyear                                                 359
# week                                                       51
# weekday                                                     5
# summary                      Possible drizzle in the evening.
# icon                                                     rain
# sunriseTime                                        1482595140
# sunsetTime                                         1482625380
# moonPhase                                                0.88
# precipIntensity                                        0.0028
# precipIntensityMax                                     0.0056
# precipIntensityMaxTime                             1.4826e+09
# precipProbability                                         0.5
# temperatureHigh                                         39.52
# temperatureHighTime                                1482613260
# temperatureLow                                          32.87
# temperatureLowTime                                 1482678660
# apparentTemperatureHigh                                 39.02
# apparentTemperatureHighTime                        1482613260
# apparentTemperatureLow                                  33.36
# apparentTemperatureLowTime                         1482678660
# dewPoint                                                34.38
# humidity                                                  0.9
# pressure                                               1013.1
# windSpeed                                                0.84
# windGust                                                 2.53
# windGustTime                                       1482614880
# windBearing                                                52
# cloudCover                                               0.96
# uvIndex                                                     1
# uvIndexTime                                        1482610080
# visibility                                                 10
# temperatureMin                                          34.38
# temperatureMinTime                                 1482643680
# temperatureMax                                          39.52
# temperatureMaxTime                                 1482613260
# apparentTemperatureMin                                  34.87
# apparentTemperatureMinTime                         1482643680
# apparentTemperatureMax                                  39.02
# apparentTemperatureMaxTime                         1482613260
# date                                2016-12-24 00:00:00-08:00
# precipType                                               rain
# precipAccumulation                                        NaN
# ozone                                                     NaN
#
#                                                             3  \
# time                                2016-12-24 08:00:00-08:00
# tweet_text                                                NaN
# wait_time                                                   0
# year                                                     2016
# month                                                      12
# day                                                        24
# hour                                                        8
# dayofyear                                                 359
# week                                                       51
# weekday                                                     5
# summary                      Possible drizzle in the evening.
# icon                                                     rain
# sunriseTime                                        1482595140
# sunsetTime                                         1482625380
# moonPhase                                                0.88
# precipIntensity                                        0.0028
# precipIntensityMax                                     0.0056
# precipIntensityMaxTime                             1.4826e+09
# precipProbability                                         0.5
# temperatureHigh                                         39.52
# temperatureHighTime                                1482613260
# temperatureLow                                          32.87
# temperatureLowTime                                 1482678660
# apparentTemperatureHigh                                 39.02
# apparentTemperatureHighTime                        1482613260
# apparentTemperatureLow                                  33.36
# apparentTemperatureLowTime                         1482678660
# dewPoint                                                34.38
# humidity                                                  0.9
# pressure                                               1013.1
# windSpeed                                                0.84
# windGust                                                 2.53
# windGustTime                                       1482614880
# windBearing                                                52
# cloudCover                                               0.96
# uvIndex                                                     1
# uvIndexTime                                        1482610080
# visibility                                                 10
# temperatureMin                                          34.38
# temperatureMinTime                                 1482643680
# temperatureMax                                          39.52
# temperatureMaxTime                                 1482613260
# apparentTemperatureMin                                  34.87
# apparentTemperatureMinTime                         1482643680
# apparentTemperatureMax                                  39.02
# apparentTemperatureMaxTime                         1482613260
# date                                2016-12-24 00:00:00-08:00
# precipType                                               rain
# precipAccumulation                                        NaN
# ozone                                                     NaN
#
#                                                             4
# time                                2016-12-24 09:00:00-08:00
# tweet_text                                                NaN
# wait_time                                                   0
# year                                                     2016
# month                                                      12
# day                                                        24
# hour                                                        9
# dayofyear                                                 359
# week                                                       51
# weekday                                                     5
# summary                      Possible drizzle in the evening.
# icon                                                     rain
# sunriseTime                                        1482595140
# sunsetTime                                         1482625380
# moonPhase                                                0.88
# precipIntensity                                        0.0028
# precipIntensityMax                                     0.0056
# precipIntensityMaxTime                             1.4826e+09
# precipProbability                                         0.5
# temperatureHigh                                         39.52
# temperatureHighTime                                1482613260
# temperatureLow                                          32.87
# temperatureLowTime                                 1482678660
# apparentTemperatureHigh                                 39.02
# apparentTemperatureHighTime                        1482613260
# apparentTemperatureLow                                  33.36
# apparentTemperatureLowTime                         1482678660
# dewPoint                                                34.38
# humidity                                                  0.9
# pressure                                               1013.1
# windSpeed                                                0.84
# windGust                                                 2.53
# windGustTime                                       1482614880
# windBearing                                                52
# cloudCover                                               0.96
# uvIndex                                                     1
# uvIndexTime                                        1482610080
# visibility                                                 10
# temperatureMin                                          34.38
# temperatureMinTime                                 1482643680
# temperatureMax                                          39.52
# temperatureMaxTime                                 1482613260
# apparentTemperatureMin                                  34.87
# apparentTemperatureMinTime                         1482643680
# apparentTemperatureMax                                  39.02
# apparentTemperatureMaxTime                         1482613260
# date                                2016-12-24 00:00:00-08:00
# precipType                                               rain
# precipAccumulation                                        NaN
# ozone                                                     NaN

# %% [markdown]
# ## Add holiday data

# %%
holidays_df = pd.read_csv('../data/holidays.csv', header=None, names=['holiday'])

# %%
holidays_df['holiday'] = pd.to_datetime(holidays_df['holiday'])
holidays_df['holiday'] = holidays_df['holiday'].dt.tz_localize('US/Pacific')

# %%
holidays_df
# Out:
#                      holiday
# 0  2016-01-01 00:00:00-08:00
# 1  2016-01-18 00:00:00-08:00
# 2  2016-02-15 00:00:00-08:00
# 3  2016-05-30 00:00:00-07:00
# 4  2016-07-04 00:00:00-07:00
# 5  2016-09-05 00:00:00-07:00
# 6  2016-11-11 00:00:00-08:00
# 7  2016-11-24 00:00:00-08:00
# 8  2016-12-26 00:00:00-08:00
# 9  2017-01-02 00:00:00-08:00
# 10 2017-01-16 00:00:00-08:00
# 11 2017-02-20 00:00:00-08:00
# 12 2017-05-29 00:00:00-07:00
# 13 2017-07-04 00:00:00-07:00
# 14 2017-09-04 00:00:00-07:00
# 15 2017-11-10 00:00:00-08:00
# 16 2017-11-23 00:00:00-08:00
# 17 2017-12-25 00:00:00-08:00
# 18 2018-01-01 00:00:00-08:00
# 19 2018-01-15 00:00:00-08:00
# 20 2018-02-19 00:00:00-08:00
# 21 2018-05-28 00:00:00-07:00
# 22 2018-07-04 00:00:00-07:00
# 23 2018-09-03 00:00:00-07:00
# 24 2018-11-12 00:00:00-08:00
# 25 2018-11-22 00:00:00-08:00
# 26 2018-12-05 00:00:00-08:00
# 27 2018-12-25 00:00:00-08:00
# 28 2020-01-01 00:00:00-08:00
# 29 2020-01-20 00:00:00-08:00
# 30 2020-02-17 00:00:00-08:00
# 31 2020-05-25 00:00:00-07:00
# 32 2020-07-03 00:00:00-07:00
# 33 2020-09-07 00:00:00-07:00
# 34 2020-11-11 00:00:00-08:00
# 35 2020-11-26 00:00:00-08:00
# 36 2020-12-25 00:00:00-08:00
# 37 2020-01-01 00:00:00-08:00

# %%
ed_wait_df = ed_wait_df.set_index(['time'])

# %%
from datetime import timedelta

# %%
ed_wait_df['holiday'] = False
for holiday in holidays_df['holiday']:
    print(holiday)
    start = holiday - timedelta(days=0)
    end = holiday + timedelta(days=1)
    print(f"{start}  {end}")
    ed_wait_df.loc[start:end, 'holiday'] = True
# Out:
# 2016-01-01 00:00:00-08:00
# 2016-01-01 00:00:00-08:00  2016-01-02 00:00:00-08:00
# 2016-01-18 00:00:00-08:00
# 2016-01-18 00:00:00-08:00  2016-01-19 00:00:00-08:00
# 2016-02-15 00:00:00-08:00
# 2016-02-15 00:00:00-08:00  2016-02-16 00:00:00-08:00
# 2016-05-30 00:00:00-07:00
# 2016-05-30 00:00:00-07:00  2016-05-31 00:00:00-07:00
# 2016-07-04 00:00:00-07:00
# 2016-07-04 00:00:00-07:00  2016-07-05 00:00:00-07:00
# 2016-09-05 00:00:00-07:00
# 2016-09-05 00:00:00-07:00  2016-09-06 00:00:00-07:00
# 2016-11-11 00:00:00-08:00
# 2016-11-11 00:00:00-08:00  2016-11-12 00:00:00-08:00
# 2016-11-24 00:00:00-08:00
# 2016-11-24 00:00:00-08:00  2016-11-25 00:00:00-08:00
# 2016-12-26 00:00:00-08:00
# 2016-12-26 00:00:00-08:00  2016-12-27 00:00:00-08:00
# 2017-01-02 00:00:00-08:00
# 2017-01-02 00:00:00-08:00  2017-01-03 00:00:00-08:00
# 2017-01-16 00:00:00-08:00
# 2017-01-16 00:00:00-08:00  2017-01-17 00:00:00-08:00
# 2017-02-20 00:00:00-08:00
# 2017-02-20 00:00:00-08:00  2017-02-21 00:00:00-08:00
# 2017-05-29 00:00:00-07:00
# 2017-05-29 00:00:00-07:00  2017-05-30 00:00:00-07:00
# 2017-07-04 00:00:00-07:00
# 2017-07-04 00:00:00-07:00  2017-07-05 00:00:00-07:00
# 2017-09-04 00:00:00-07:00
# 2017-09-04 00:00:00-07:00  2017-09-05 00:00:00-07:00
# 2017-11-10 00:00:00-08:00
# 2017-11-10 00:00:00-08:00  2017-11-11 00:00:00-08:00
# 2017-11-23 00:00:00-08:00
# 2017-11-23 00:00:00-08:00  2017-11-24 00:00:00-08:00
# 2017-12-25 00:00:00-08:00
# 2017-12-25 00:00:00-08:00  2017-12-26 00:00:00-08:00
# 2018-01-01 00:00:00-08:00
# 2018-01-01 00:00:00-08:00  2018-01-02 00:00:00-08:00
# 2018-01-15 00:00:00-08:00
# 2018-01-15 00:00:00-08:00  2018-01-16 00:00:00-08:00
# 2018-02-19 00:00:00-08:00
# 2018-02-19 00:00:00-08:00  2018-02-20 00:00:00-08:00
# 2018-05-28 00:00:00-07:00
# 2018-05-28 00:00:00-07:00  2018-05-29 00:00:00-07:00
# 2018-07-04 00:00:00-07:00
# 2018-07-04 00:00:00-07:00  2018-07-05 00:00:00-07:00
# 2018-09-03 00:00:00-07:00
# 2018-09-03 00:00:00-07:00  2018-09-04 00:00:00-07:00
# 2018-11-12 00:00:00-08:00
# 2018-11-12 00:00:00-08:00  2018-11-13 00:00:00-08:00
# 2018-11-22 00:00:00-08:00
# 2018-11-22 00:00:00-08:00  2018-11-23 00:00:00-08:00
# 2018-12-05 00:00:00-08:00
# 2018-12-05 00:00:00-08:00  2018-12-06 00:00:00-08:00
# 2018-12-25 00:00:00-08:00
# 2018-12-25 00:00:00-08:00  2018-12-26 00:00:00-08:00
# 2020-01-01 00:00:00-08:00
# 2020-01-01 00:00:00-08:00  2020-01-02 00:00:00-08:00
# 2020-01-20 00:00:00-08:00
# 2020-01-20 00:00:00-08:00  2020-01-21 00:00:00-08:00
# 2020-02-17 00:00:00-08:00
# 2020-02-17 00:00:00-08:00  2020-02-18 00:00:00-08:00
# 2020-05-25 00:00:00-07:00
# 2020-05-25 00:00:00-07:00  2020-05-26 00:00:00-07:00
# 2020-07-03 00:00:00-07:00
# 2020-07-03 00:00:00-07:00  2020-07-04 00:00:00-07:00
# 2020-09-07 00:00:00-07:00
# 2020-09-07 00:00:00-07:00  2020-09-08 00:00:00-07:00
# 2020-11-11 00:00:00-08:00
# 2020-11-11 00:00:00-08:00  2020-11-12 00:00:00-08:00
# 2020-11-26 00:00:00-08:00
# 2020-11-26 00:00:00-08:00  2020-11-27 00:00:00-08:00
# 2020-12-25 00:00:00-08:00
# 2020-12-25 00:00:00-08:00  2020-12-26 00:00:00-08:00
# 2020-01-01 00:00:00-08:00
# 2020-01-01 00:00:00-08:00  2020-01-02 00:00:00-08:00

# %%
ed_wait_df['holiday'].head(480)
# Out:
# time
# 2016-12-24 05:00:00-08:00    False
# 2016-12-24 06:00:00-08:00    False
# 2016-12-24 07:00:00-08:00    False
# 2016-12-24 08:00:00-08:00    False
# 2016-12-24 09:00:00-08:00    False
#                              ...
# 2017-01-15 18:00:00-08:00    False
# 2017-01-15 19:00:00-08:00    False
# 2017-01-15 20:00:00-08:00    False
# 2017-01-15 21:00:00-08:00    False
# 2017-01-15 22:00:00-08:00    False
# Name: holiday, Length: 480, dtype: bool

# %%
ed_wait_df.loc[start:end, 'holiday']
# Out:
# Series([], Name: holiday, dtype: bool)
